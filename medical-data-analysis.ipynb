# %%
import pandas as pd
import numpy as np

# Load the dataset
data = pd.read_csv("medical_data.csv")

# Display first few rows of the dataset
print("Dataset Preview:")
print(data.head())

# Calculate average vitals
average_vitals = data.mean(numeric_only=True)
print("\nAverage Vitals:")
print(average_vitals)

# Statistical summary of the data
print("\nStatistical Summary:")
print(data.describe())

# Calculate abnormal readings
# Thresholds for high and low blood pressure
bp_high_threshold = 140
bp_low_threshold = 90

# Calculation of abnormal readings for Blood Pressure
abnormal_data_bp = data[
    (data["Blood Pressure"] > bp_high_threshold) |
    (data["Blood Pressure"] < bp_low_threshold)
]

# Print abnormal readings
print("Abnormal Readings (Blood Pressure):")
print(abnormal_data_bp)
# Out:
# Dataset Preview:
#    Patient ID  Age Gender  Blood Pressure  Heart Rate        Date  \
# 0           1   56      F              93          99  2025-01-01
# 1           2   69      F             112          60  2025-01-02
# 2           3   46      F             104          70  2025-01-03
# 3           4   32      F             132          87  2025-01-04
# 4           5   60      M             118         116  2025-01-05
#
#    Body Temperature (°F)  Respiratory Rate (breaths/min)  \
# 0                   98.2                              24
# 1                  100.8                              16
# 2                   99.8                              10
# 3                   99.2                              13
# 4                   97.2                              22
#
#    Oxygen Saturation (%)
# 0                     99
# 1                     95
# 2                     96
# 3                     93
# 4                     96
#
# Average Vitals:
# ...
